# %%
# import the required libraries for data set

import pandas as pd
import numpy as np
import seaborn as sns

# %%
# loading the dataset

file_path = r"D:\Dummy\Employee Sample Data1.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 944  E03094     Wesley Young               Sr. Analyst   Marketing
# 945  E01909     Lillian Khan                   Analyst     Finance
# 946  E04398      Oliver Yang                  Director   Marketing
# 947  E02521      Lily Nguyen               Sr. Analyst     Finance
# 948  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age Hire Date.1 Annual Salary  \
# 0    Research & Development  Female      Black   55  04-08-2016      $141,604
# ...

# %%
df.shape
# Out:
# (949, 14)

# %%
df.size
# Out:
# 13286

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949 entries, 0 to 948
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           949 non-null    object
#  1   Full Name      949 non-null    object
#  2   Job Title      949 non-null    object
#  3   Department     949 non-null    object
#  4   Business Unit  949 non-null    object
#  5   Gender         949 non-null    object
#  6   Ethnicity      949 non-null    object
#  7   Age            949 non-null    int64
#  8   Hire Date.1    949 non-null    object
#  9   Annual Salary  949 non-null    object
#  10  Bonus %        949 non-null    float64
#  11  Country        949 non-null    object
#  12  City           949 non-null    object
#  13  Exit Date      82 non-null     object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 103.9+ KB

# %%
df.isnull()
# Out:
#       EEID  Full Name  Job Title  Department  Business Unit  Gender  \
# 0    False      False      False       False          False   False
# 1    False      False      False       False          False   False
# 2    False      False      False       False          False   False
# 3    False      False      False       False          False   False
# 4    False      False      False       False          False   False
# ..     ...        ...        ...         ...            ...     ...
# 944  False      False      False       False          False   False
# 945  False      False      False       False          False   False
# 946  False      False      False       False          False   False
# 947  False      False      False       False          False   False
# 948  False      False      False       False          False   False
#
#      Ethnicity    Age  Hire Date.1  Annual Salary  Bonus %  Country   City  \
# ...

# %%
df.isna()
# Out:
#       EEID  Full Name  Job Title  Department  Business Unit  Gender  \
# 0    False      False      False       False          False   False
# 1    False      False      False       False          False   False
# 2    False      False      False       False          False   False
# 3    False      False      False       False          False   False
# 4    False      False      False       False          False   False
# ..     ...        ...        ...         ...            ...     ...
# 944  False      False      False       False          False   False
# 945  False      False      False       False          False   False
# 946  False      False      False       False          False   False
# 947  False      False      False       False          False   False
# 948  False      False      False       False          False   False
#
#      Ethnicity    Age  Hire Date.1  Annual Salary  Bonus %  Country   City  \
# ...

# %%
df.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date.1        0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        867
# dtype: int64

# %%
df.nunique()
# Out:
# EEID             871
# Full Name        941
# Job Title         33
# Department         7
# Business Unit      4
# Gender             2
# Ethnicity          4
# Age               41
# Hire Date.1      949
# Annual Salary    945
# Bonus %           37
# Country            3
# City              13
# Exit Date         80
# dtype: int64

# %%
df.dtypes
# Out:
# EEID              object
# Full Name         object
# Job Title         object
# Department        object
# Business Unit     object
# Gender            object
# Ethnicity         object
# Age                int64
# Hire Date.1       object
# Annual Salary     object
# Bonus %          float64
# Country           object
# City              object
# Exit Date         object
# dtype: object

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date.1', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
df.count()
# Out:
# EEID             949
# Full Name        949
# Job Title        949
# Department       949
# Business Unit    949
# Gender           949
# Ethnicity        949
# Age              949
# Hire Date.1      949
# Annual Salary    949
# Bonus %          949
# Country          949
# City             949
# Exit Date         82
# dtype: int64

# %%
df.describe() # only numeric values have shows the describe function
# Out:
#               Age     Bonus %
# count  949.000000  949.000000
# mean    44.611170    0.088440
# std     11.257699    0.117469
# min     25.000000    0.000000
# 25%     35.000000    0.000000
# 50%     45.000000    0.000000
# 75%     54.000000    0.150000
# max     65.000000    0.400000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x000001AF4A923100>

# %%
df.ndim
# Out:
# 2

# %%
df.value_counts()
# Out:
# EEID    Full Name       Job Title              Department   Business Unit           Gender  Ethnicity  Age  Hire Date.1  Annual Salary  Bonus %  Country        City       Exit Date
# E00119  Jack Maldonado  Director               Engineering  Research & Development  Male    Latino     31   8/26/2020    $189,290       0.22     Brazil         Sao Paulo  9/25/2020              1
# E03758  Liam Zhang      Director               Marketing    Research & Development  Male    Asian      29   9/15/2021    $199,783       0.21     United States  Chicago    04-10-2022 00:00:00    1
# E03579  Robert Zhang    Vice President         Marketing    Corporate               Male    Asian      45   9/24/2015    $202,680       0.32     United States  Phoenix    8/17/2022              1
# E03563  Ian Barnes      Operations Engineer    Engineering  Corporate               Male    Caucasian  47   06-08-2020   $115,765       0.00     United States  Miami      02-02-2021 00:00:00    1
# ...
