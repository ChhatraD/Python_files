# %%
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\chhat\Computer_Code\Row_data\movies.csv"

# %%
df2 = pd.read_csv(r"C:\Users\chhat\Desktop\cleaned_movie_data.csv")

# %%
df2
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 5950                     Disparu à jamais       (2021)
# 5951                        Modern Family  (2009–2020)
# 5952                            Totenfrau     (2022– )
# 5953                               Arcane     (2021– )
# 5954                    Heart of Invictus     (2022– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df2.describe()
# Out:
#             RATING      RunTime        Gross
# count  5955.000000  5036.000000  5955.000000
# mean      6.619647    79.925139     3.247560
# std       1.167889    49.278663    24.696649
# min       1.100000     1.000000     0.000000
# 25%       5.900000    47.000000     0.000000
# 50%       6.800000    84.000000     0.000000
# 75%       7.400000   101.000000     0.000000
# max       9.400000   853.000000   486.300000

# %%
#df.corr()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    5955 non-null   object
#  1   YEAR      5955 non-null   object
#  2   GENRE     5955 non-null   object
#  3   RATING    5955 non-null   float64
#  4   ONE-LINE  5955 non-null   object
#  5   STARS     5801 non-null   object
#  6   VOTES     5482 non-null   object
#  7   RunTime   5036 non-null   float64
#  8   Gross     5955 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 418.8+ KB

# %%
df.shape
# Out:
# (9026, 9)

# %%
#df.plot
#plt.show()

# %%
df2.size
# Out:
# 53595

# %%
df.count().sum() # count work only on non-null values, but size counte everthing included NAN values
# Out:
# 73130

# %%
df.sample(10)
# Out:
#                                   MOVIES         YEAR  \
# 5280                      The Chefs Line     (2017– )
# 8685                              Dexter  (2006–2013)
# 4641  The Reconstruction of William Zero       (2014)
# 2716                    Criminal: France     (2019– )
# 1562       Romaenseuneun Byulchaekboorok       (2019)
# 1970                   Tarde para la ira       (2016)
# 7071                   Aseudal Yeondaegi     (2019– )
# 8419                               Buddi     (2020– )
# 831        The Suite Life of Zack & Cody  (2005–2008)
# 9                           Virgin River     (2019– )
#
#                                      GENRE  RATING  \
# 5280              \nReality-TV                 7.0
# 8685   \nCrime, Drama, Mystery                 8.8
# 4641  \nDrama, Mystery, Sci-Fi                 5.4
# 2716   \nCrime, Drama, Mystery                 7.2
# 1562                 \nRomance                 8.1
# 1970    \nAction, Crime, Drama                 6.8
# ...

# %%
df2.isnull().sum()
# Out:
# MOVIES        0
# YEAR          0
# GENRE         0
# RATING        0
# ONE-LINE      0
# STARS       154
# VOTES       473
# RunTime     919
# Gross         0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 1546

# %%
round(df2.isnull().sum().sum() / df2.size * 100, 4) #how much % of null value present in your dataset, 4 is decimal points to show
# Out:
# 2.8846

# %%
df2.duplicated(subset=["MOVIES"]).value_counts()  # value_counts methods is used to see the total values of true and false individually
# Out:
# False    5955
# Name: count, dtype: int64

# %%
df.duplicated(subset=["MOVIES"]).value_counts()
# Out:
# False    6817
# True     3182
# Name: count, dtype: int64

# %%
df2[df2.duplicated()].count()
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RunTime     0
# Gross       0
# dtype: int64

# %%
df[df.duplicated()].count()
# Out:
# MOVIES      431
# YEAR        329
# GENRE       429
# RATING       11
# ONE-LINE    431
# STARS       431
# VOTES        11
# RunTime      33
# Gross         0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                     MOVIES      YEAR  \
# 6833   Mighty Little Bheem  (2019– )
# 6835   Mighty Little Bheem  (2019– )
# 6836   Mighty Little Bheem  (2019– )
# 6837   Mighty Little Bheem  (2019– )
# 6838   Mighty Little Bheem  (2019– )
# ...                    ...       ...
# 9989                  1899  (2022– )
# 9990                  1899  (2022– )
# 9991                  1899  (2022– )
# 9992                  1899  (2022– )
# 9994        The Imperfects  (2021– )
#
#                                           GENRE  RATING        ONE-LINE  \
# 6833  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# 6835  \nAnimation, Short, Adventure                 9.0  \nAdd a Plot\n
# 6836  \nAnimation, Short, Adventure                 9.0  \nAdd a Plot\n
# 6837  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# 6838  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# ...                                         ...     ...             ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(234)
# Out:
# <Axes: >

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.drop("Gross", axis=1)
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.YEAR
# Out:
# 0            (2021)
# 1          (2021– )
# 2       (2010–2022)
# 3          (2013– )
# 4            (2021)
#            ...
# 9993       (2022– )
# 9995       (2021– )
# 9996       (2022– )
# 9997       (2021– )
# 9998       (2021– )
# Name: YEAR, Length: 9568, dtype: object

# %%
df['YEAR'].str.strip('().—,/')
# Out:
# 0            2021
# 1          2021–
# 2       2010–2022
# 3          2013–
# 4            2021
#           ...
# 9993       2022–
# 9995       2021–
# 9996       2022–
# 9997       2021–
# 9998       2021–
# Name: YEAR, Length: 9568, dtype: object

# %%
pd.set_option("display.max_columns", 10)
pd.set_option("display.max_rows", 10)

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.nunique(axis=0, dropna=True)
# Out:
# MOVIES      6817
# YEAR         438
# GENRE        510
# RATING        82
# ONE-LINE    8688
# STARS       7877
# VOTES       4129
# RunTime      261
# Gross        332
# dtype: int64

# %%
df.nunique(axis=1, dropna=True)
# Out:
# 0       8
# 1       8
# 2       8
# 3       8
# 4       5
#        ..
# 9993    5
# 9995    5
# 9996    5
# 9997    5
# 9998    5
# Length: 9568, dtype: int64

# %%
new_date= df['YEAR'].str.replace('[^0-9]','',regex=True)

new_date
# Out:
# 0           2021
# 1           2021
# 2       20102022
# 3           2013
# 4           2021
#           ...
# 9993        2022
# 9995        2021
# 9996        2022
# 9997        2021
# 9998        2021
# Name: YEAR, Length: 9568, dtype: object

# %%
df.isnull().sum()
# Out:
# MOVIES         0
# YEAR           0
# GENRE         37
# RATING       858
# ONE-LINE       0
# STARS          0
# VOTES        858
# RunTime     2039
# Gross       8566
# dtype: int64

# %%
df['YEAR'].dtype
# Out:
# dtype('O')

# %%
pd.options.mode.chained_assignment = None

# %%
df['YEAR']= df['YEAR'].astype(str).astype(int, errors='ignore')

# %%
df.YEAR.nunique()
# Out:
# 438

# %%
df.YEAR.unique()
# Out:
# array(['(2021)', '(2021– )', '(2010–2022)', '(2013– )', '(2020– )',
#        '(2006–2013)', '(2019– )', '(2016–2021)', '(2011– )', '(2005– )',
#        '(2008–2013)', '(2017– )', '(2017–2021)', '(2016– )',
#        '(1994–2004)', '(2014– )', '(2013–2020)', '(2015– )',
#        '(2005–2020)', '(2013–2022)', '(2003– )', '(2009–2020)',
#        '(I) (2018– )', '(2010–2015)', '(2011–2019)', '(2015–2020)',
#        '(2005–2014)', '(2009–2015)', '(2008–2014)', '(2016–2018)',
#        '(2009–2017)', '(2020)', '(2018–2021)', '(2017–2020)',
#        '(1987–1994)', '(2018– )', '(2012– )', '(2014–2020)',
#        '(2011–2018)', '(2005–2017)', '(2017)', '(2007–2015)',
#        '(2000–2007)', '(II) (2007– )', '(1993)', '(1999–2022)',
#        '(2015–2018)', '(2014–2019)', '(2016)', '(2012–2020)',
#        '(2013–2019)', '(2007–2012)', '(2011–2020)', '(2010–2017)',
#        '(2000–2015)', '(2015–2021)', '(2001)', '(1997– )', '(2011–2017)',
# ...

# %%
trimmed_dates = [date[:4] for date in new_date]
print(trimmed_dates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 trimmed_dates = [date[:4] for date in new_date]
#       2 print(trimmed_dates)
#
# TypeError: 'float' object is not subscriptable

# %%
for trimmed_date in trimmed_dates:
    print(trimmed_date)
# Out:
# 2021
# 2021
# 2010
# 2013
# 2021
# 2020
# 2021
# 2006
# 2020
# 2019
# 2021
# 2016
# 2021
# 2021
# 2011
# 2005
# 2008
# 2017
# 2017
# 2016
# 2021
# 1994
# 2014
# 2013
# 2021
# 2021
# 2013
# 2015
# 2005
# 2013
# 2021
# 2016
# 2013
# 2003
# 2019
# 2009
# 2018
# 2019
# 2010
# 2013
# 2011
# 2017
# 2015
# 2014
# 2015
# 2011
# 2017
# 2016
# 2021
# 2021
# 2014
# 2005
# 2009
# 2008
# 2016
# 2009
# 2020
# 2019
# 2018
# 2017
# 2020
# 2016
# 1987
# 2021
# 2021
# 2019
# 2015
# 2018
# 2012
# 2014
# 2011
# 2005
# 2019
# 2021
# 2021
# 2021
# 2021
# 2017
# 2007
# 2018
# 2000
# 2021
# 2021
# 2021
# 2007
# 1993
# 1999
# 2015
# 2017
# 2016
# 2018
# 2019
# 2014
# 2016
# 2013
# 2016
# 2021
# 2012
# 2013
# 2007
# 2020
# 2018
# 2011
# 2017
# 2010
# 2021
# 2016
# 2000
# 2019
# 2015
# 2014
# 2001
# 2019
# 1997
# 2011
# 2017
# 2011
# 2014
# 1993
# 1989
# 2010
# 2010
# 2015
# 2017
# 2003
# 2019
# 2018
# 2017
# 1975
# 2005
# 2017
# 1995
# 2006
# 2015
# 2021
# 2008
# 1984
# 2021
# 2010
# 2021
# 2021
# 2019
# ...

# %%
df.loc[:, 'YEAR'] = trimmed_dates

# %%
df.YEAR.convert_dtypes(int())
# Out:
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2021
#         ...
# 9993    2022
# 9995    2021
# 9996    2022
# 9997    2021
# 9998    2021
# Name: YEAR, Length: 9026, dtype: string

# %%
df.YEAR.convert_dtypes(str())
# Out:
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2021
#         ...
# 9993    2022
# 9995    2021
# 9996    2022
# 9997    2021
# 9998    2021
# Name: YEAR, Length: 9026, dtype: string

# %%
df.YEAR.replace(int())
# Out:
# C:\Users\chhat\AppData\Local\Temp\ipykernel_7680\2000339867.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df.YEAR.replace(int())
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2021
#         ...
# 9993    2022
# 9995    2021
# 9996    2022
# 9997    2021
# 9998    2021
# Name: YEAR, Length: 9026, dtype: object

# %%
df.YEAR.unique()
# Out:
# array(['2021', '2010', '2013', '2020', '2006', '2019', '2016', '2011',
#        '2005', '2008', '2017', '1994', '2014', '2015', '2003', '2009',
#        '2018', '1987', '2012', '2007', '2000', '1993', '1999', '2001',
#        '1997', '1989', '1975', '1995', '1984', '1998', '1966', '1990',
#        '2002', '1976', '1978', '2022', '1982', '1968', '2004', '1996',
#        '1971', '1980', '1962', '1991', '1960', '1988', '1969', '1961',
#        '1979', '1956', '1983', '1986', '1967', '1974', '', '1992', '1958',
#        '1932', '1941', '1950', '1946', '1981', '1952', '1957', '1954',
#        '1955', '1948', '1947', '1977', '2023', '1945', '1953', '1985',
#        '1973', '1972', '1965', '1944', '1933', '1938'], dtype=object)

# %%
df["YEAR"]= df["YEAR"].astype("datetime64[ns]")

# %%
df.YEAR
# Out:
# 0      2021-01-01
# 1      2021-01-01
# 2      2010-01-01
# 3      2013-01-01
# 4      2021-01-01
#           ...
# 9993   2022-01-01
# 9995   2021-01-01
# 9996   2022-01-01
# 9997   2021-01-01
# 9998   2021-01-01
# Name: YEAR, Length: 9026, dtype: datetime64[ns]
