# %%
import pandas as pd
import numpy as np

# %%
# check pandas version
print(pd.__version__)
# Out:
# 2.1.4

# %%
file_path = r"C:\Users\chhat\Computer_Code\Dummy_Data\movies1.csv"

# %%
df = pd.read_csv(file_path, encoding='unicode_escape')

# %%
df
# Out:
#                                    MOVIES  YEAR                         GENRE  \
# 0                           Blood Red Sky  2021      Action, Horror, Thriller
# 1     Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 2                        The Walking Dead  2010       Drama, Horror, Thriller
# 3                          Rick and Morty  2013  Animation, Adventure, Comedy
# 4                             Outer Banks  2020          Action, Crime, Drama
# ...                                   ...   ...                           ...
# 6526                               Sexify  2021                 Comedy, Drama
# 6527                               Sexify  2021                 Comedy, Drama
# 6528                               Sexify  2021                 Comedy, Drama
# 6529                               Sexify  2021                 Comedy, Drama
# 6530                          Castlevania  2017  Animation, Action, Adventure
#
# ...

# %%
df.head(0) # shows the only columns name in your data

df.head()
# Out:
#                                 MOVIES  YEAR                         GENRE  \
# 0                        Blood Red Sky  2021      Action, Horror, Thriller
# 1  Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 2                     The Walking Dead  2010       Drama, Horror, Thriller
# 3                       Rick and Morty  2013  Animation, Adventure, Comedy
# 4                          Outer Banks  2020          Action, Crime, Drama
#
#    RATING                                           ONE-LINE  \
# 0     6.1  A woman with a mysterious illness is forced in...
# 1     5.0  The war for Eternia begins again in what may b...
# 2     8.2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3     9.2  An animated series that follows the exploits o...
# 4     7.6  A group of teenagers from the wrong side of th...
#
#                                                STARS   VOTES  RunTime
# 0  Director:Peter Thorwarth|     Stars:Peri Baume...   21062      121
# ...

# %%
df.tail()
# Out:
#            MOVIES  YEAR                         GENRE  RATING  \
# 6526       Sexify  2021                 Comedy, Drama     6.8
# 6527       Sexify  2021                 Comedy, Drama     7.1
# 6528       Sexify  2021                 Comedy, Drama     6.9
# 6529       Sexify  2021                 Comedy, Drama     7.1
# 6530  Castlevania  2017  Animation, Action, Adventure     8.2
#
#                                                ONE-LINE  \
# 6526  Monika's idea for gathering data is a hit, but...
# 6527  After facing their parents at Easter breakfast...
# 6528  After getting an anonymous tip about the copul...
# 6529  The big pitch at the university tech competiti...
# 6530  Lenore urges Hector to not test Camilla's pati...
#
#                                                   STARS  VOTES  RunTime
# 6526  Director:Kalina Alabrudzinska|     Stars:Aleks...    108       38
# 6527  Director:Kalina Alabrudzinska|     Stars:Aleks...    103       37
# ...

# %%
df.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6531, step=1)

# %%
df.value_counts()
# Out:
# MOVIES                                                       YEAR  GENRE                            RATING  ONE-LINE                                                                                                                                                                                                                       STARS                                                                                                                 VOTES  RunTime
# #AnneFrank - Parallel Stories                                2019  Drama, History                   6.5     It is based on five women who did survive the Holocaust but shared her same fate of "deportation, suffering and being denied their childhood and adolescence," according to promotional materials.                             Directors:Sabina Fedeli, Anna Migotto|     Stars:Helen Mirren, Anne Frank, Martina Gatti, Arianna Szorenyi            1296   92         1
# ...

# %%
df.values
# Out:
# array([['Blood Red Sky', 2021, 'Action, Horror, Thriller', ...,
#         'Director:Peter Thorwarth|     Stars:Peri Baumeister, Carl Anton Koch, Alexander Scheer, Kais Setti',
#         21062, 121],
#        ['Masters of the Universe: Revelation', 2021,
#         'Animation, Action, Adventure', ...,
#         'Stars:Chris Wood, Sarah Michelle Gellar, Lena Headey, Mark Hamill',
#         17870, 25],
#        ['The Walking Dead', 2010, 'Drama, Horror, Thriller', ...,
#         'Stars:Andrew Lincoln, Norman Reedus, Melissa McBride, Lauren Cohan',
#         885805, 44],
#        ...,
#        ['Sexify', 2021, 'Comedy, Drama', ...,
#         'Director:Kalina Alabrudzinska|     Stars:Aleksandra Skraba, Maria Sobocinska, Sandra Drzymalska, Piotr Pacek',
#         96, 40],
#        ['Sexify', 2021, 'Comedy, Drama', ...,
#         'Director:Kalina Alabrudzinska|     Stars:Aleksandra Skraba, Maria Sobocinska, Sandra Drzymalska, Piotr Pacek',
#         100, 47],
# ...

# %%
df.describe()
# Out:
#               YEAR       RATING         VOTES      RunTime
# count  6531.000000  6531.000000  6.531000e+03  6531.000000
# mean   2015.241004     6.893294  1.749290e+04    68.427653
# std       8.210633     1.239319  7.602795e+04    47.567630
# min    1932.000000     1.100000  5.000000e+00     1.000000
# 25%    2014.000000     6.200000  2.795000e+02    35.000000
# 50%    2018.000000     7.100000  1.188000e+03    60.000000
# 75%    2019.000000     7.800000  4.859000e+03    94.000000
# max    2021.000000     9.900000  1.713028e+06   853.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6531 entries, 0 to 6530
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    6531 non-null   object
#  1   YEAR      6531 non-null   int32
#  2   GENRE     6524 non-null   object
#  3   RATING    6531 non-null   float64
#  4   ONE-LINE  6531 non-null   object
#  5   STARS     6502 non-null   object
#  6   VOTES     6531 non-null   int64
#  7   RunTime   6531 non-null   int64
# dtypes: float64(1), int32(1), int64(2), object(4)
# memory usage: 382.8+ KB

# %%
# to change the datatype of YEAR column form int64 to int32

df['YEAR']=df['YEAR'].astype('int32')

# %%
df.shape
# Out:
# (6531, 8)

# %%
df.size
# Out:
# 52248

# %%
df.isnull().sum()
# Out:
# MOVIES       0
# YEAR         0
# GENRE        7
# RATING       0
# ONE-LINE     0
# STARS       29
# VOTES        0
# RunTime      0
# dtype: int64

# %%
df.isnull().sum().sum() # it shows the total number of NAN in your dataset
# Out:
# 36

# %%
round(df.isna().sum().sum() / df.size * 100, 1) #to shows the total % of null values in your dataset
# Out:
# 0.1

# %%
df[df.duplicated()]  # check duplicated rows
# Out:
# Empty DataFrame
# Columns: [MOVIES, YEAR, GENRE, RATING, ONE-LINE, STARS, VOTES, RunTime]
# Index: []

# %%
df = df.dropna(subset=['GENRE'])   #it remove the NA value from "GENRE" column

# %%
# to delete the unwanted column, 1 for columns and 0 for rows

#df= df.drop("Gross", axis=1)

# %%
#df.to_string()

# %%
# df= pd.set_option("display.max_columns", 20)
# print(df)

# %%
rows = df.sample(frac=.0002)  # this shows the 0.0002% of data of df

# %%
# find unique values in rows or columns

df.nunique(axis=1, dropna=True)

df.nunique(axis=0, dropna=True)
# Out:
# MOVIES      4726
# YEAR          76
# GENRE        456
# RATING        82
# ONE-LINE    6373
# STARS       5690
# VOTES       3883
# RunTime      259
# dtype: int64

# %%
# pd.set_option("display.max_columns", 15)
# pd.set_option("display.max_rows", 15)

# %%
df
# Out:
#                                    MOVIES  YEAR                         GENRE  \
# 0                           Blood Red Sky  2021      Action, Horror, Thriller
# 1     Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 2                        The Walking Dead  2010       Drama, Horror, Thriller
# 3                          Rick and Morty  2013  Animation, Adventure, Comedy
# 4                             Outer Banks  2020          Action, Crime, Drama
# ...                                   ...   ...                           ...
# 6526                               Sexify  2021                 Comedy, Drama
# 6527                               Sexify  2021                 Comedy, Drama
# 6528                               Sexify  2021                 Comedy, Drama
# 6529                               Sexify  2021                 Comedy, Drama
# 6530                          Castlevania  2017  Animation, Action, Adventure
#
# ...

# %%
df.isnull().sum()
# Out:
# MOVIES       0
# YEAR         0
# GENRE        0
# RATING       0
# ONE-LINE     0
# STARS       29
# VOTES        0
# RunTime      0
# dtype: int64

# %%
df.isnull().sum().sum()  # to show the total null value of your dataset
# Out:
# 29

# %%
df.filter(items=["MainBranch", "Hobbyist"], axis=1)  #to filter out the columns


df.filter(items=[5], axis=0) # to filter out rows on basis of index number
# Out:
#                             MOVIES  YEAR           GENRE  RATING  \
# 5  The Last Letter from Your Lover  2021  Drama, Romance     6.8
#
#                                             ONE-LINE  \
# 5  A pair of interwoven stories set in the past a...
#
#                                                STARS  VOTES  RunTime
# 5  Director:Augustine Frizzell|     Stars:Shailen...   5283      110

# %%
#df.filter(like="East Asian", axis=0)

# %%
df.drop([2,3,4,5], axis=0) # drop the rows by using index
# Out:
#                                    MOVIES  YEAR                         GENRE  \
# 0                           Blood Red Sky  2021      Action, Horror, Thriller
# 1     Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 6                                  Dexter  2006         Crime, Drama, Mystery
# 7                       Never Have I Ever  2020                        Comedy
# 8                            Virgin River  2019                Drama, Romance
# ...                                   ...   ...                           ...
# 6526                               Sexify  2021                 Comedy, Drama
# 6527                               Sexify  2021                 Comedy, Drama
# 6528                               Sexify  2021                 Comedy, Drama
# 6529                               Sexify  2021                 Comedy, Drama
# 6530                          Castlevania  2017  Animation, Action, Adventure
#
# ...

# %%
#df.drop(["MainBranch","Hobbyist"], inplace=True, axis=1)  # to drop any columns by using label or columns name, inplace use if u want to parmanent change in main data

# %%
# use of loc and iloc

# loc for location or label based, and in slicing like 1:5, then 5 included in output data
# iloc for index based, and in slicing like 1:5, then 5 will be not included in output data

# %%
df.fillna("ram")  # this method just fill all the data which have "NaN" with "ram"

df.dropna()  # just drop all the rows which have the NaN value, remaining rows will be shows.

df.isna() # or df.isnull() both are same, wherever the value NaN present it will shows True, otherwise False
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime
# 0      False  False  False   False     False  False  False    False
# 1      False  False  False   False     False  False  False    False
# 2      False  False  False   False     False  False  False    False
# 3      False  False  False   False     False  False  False    False
# 4      False  False  False   False     False  False  False    False
# ...      ...    ...    ...     ...       ...    ...    ...      ...
# 6526   False  False  False   False     False  False  False    False
# 6527   False  False  False   False     False  False  False    False
# 6528   False  False  False   False     False  False  False    False
# 6529   False  False  False   False     False  False  False    False
# 6530   False  False  False   False     False  False  False    False
#
# [6524 rows x 8 columns]

# %%
df.columns= [x.upper() for x in df.columns]

# %%
df.columns = df.columns.str.replace(",", "_")

# %%
# renaming columns

df.rename(columns = {"C":"A"})  # using rename function and pass the dict old value, new value
# Out:
#                                    MOVIES  YEAR                         GENRE  \
# 0                           Blood Red Sky  2021      Action, Horror, Thriller
# 1     Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 2                        The Walking Dead  2010       Drama, Horror, Thriller
# 3                          Rick and Morty  2013  Animation, Adventure, Comedy
# 4                             Outer Banks  2020          Action, Crime, Drama
# ...                                   ...   ...                           ...
# 6526                               Sexify  2021                 Comedy, Drama
# 6527                               Sexify  2021                 Comedy, Drama
# 6528                               Sexify  2021                 Comedy, Drama
# 6529                               Sexify  2021                 Comedy, Drama
# 6530                          Castlevania  2017  Animation, Action, Adventure
#
# ...

# %%
# to clean all the data which have extra characters like -, \ / ... anthing which are not required

        # df['Last_Name'] = df['Last_Name'].str.lstrip('...')
        # df['Last_Name'] = df['Last_Name'].str.lstrip('/')
        # df['Last_Name'] = df['Last_Name'].str.rstrip('_')



            # OR to apply one single code for all
            
# df['Last_Name'].str.strip('123._/')

# %%
df.STARS.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6526    False
# 6527    False
# 6528    False
# 6529    False
# 6530    False
# Name: STARS, Length: 6524, dtype: bool

# %%
df.STARS.isna()    #the method .isna or .isnull both are same and both work same, there is no difference
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6526    False
# 6527    False
# 6528    False
# 6529    False
# 6530    False
# Name: STARS, Length: 6524, dtype: bool

# %%
df= df.dropna(subset=['STARS'])

# %%
df['RATING'] = df['RATING'].round(1)

df
# Out:
# C:\Users\chhat\AppData\Local\Temp\ipykernel_9780\1226060847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RATING'] = df['RATING'].round(1)
#                                    MOVIES  YEAR                         GENRE  \
# 0                           Blood Red Sky  2021      Action, Horror, Thriller
# 1     Masters of the Universe: Revelation  2021  Animation, Action, Adventure
# 2                        The Walking Dead  2010       Drama, Horror, Thriller
# 3                          Rick and Morty  2013  Animation, Adventure, Comedy
# 4                             Outer Banks  2020          Action, Crime, Drama
# ...                                   ...   ...                           ...
# ...

# %%
pd.options.mode.chained_assignment = None  # this is for error removing command

# %%
df['VOTES']= df['VOTES'].astype(float).astype(int, errors='ignore') #to convert datatype from float to int

# %%
df = df.dropna(subset=['VOTES'])

# %%
df.isnull().sum()
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RUNTIME     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6495 entries, 0 to 6530
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    6495 non-null   object
#  1   YEAR      6495 non-null   int64
#  2   GENRE     6495 non-null   object
#  3   RATING    6495 non-null   float64
#  4   ONE-LINE  6495 non-null   object
#  5   STARS     6495 non-null   object
#  6   VOTES     6495 non-null   int32
#  7   RUNTIME   6495 non-null   int64
# dtypes: float64(1), int32(1), int64(2), object(4)
# memory usage: 431.3+ KB

# %%
df.YEAR
# Out:
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2020
#         ...
# 6526    2021
# 6527    2021
# 6528    2021
# 6529    2021
# 6530    2017
# Name: YEAR, Length: 6495, dtype: int64

# %%
df.GENRE.unique()
# Out:
# array(['Action, Horror, Thriller', 'Animation, Action, Adventure',
#        'Drama, Horror, Thriller', 'Animation, Adventure, Comedy',
#        'Action, Crime, Drama', 'Drama, Romance', 'Crime, Drama, Mystery',
#        'Comedy', 'Action, Adventure, Thriller', 'Crime, Drama, Fantasy',
#        'Drama, Horror, Mystery', 'Crime, Drama, Thriller', 'Drama',
#        'Comedy, Drama', 'Drama, Fantasy, Horror', 'Comedy, Romance',
#        'Action, Adventure, Drama', 'Crime, Drama',
#        'Drama, History, Romance', 'Horror, Mystery', 'Comedy, Crime',
#        'Action, Drama, History', 'Comedy, Drama, Romance',
#        'Action, Adventure, Fantasy', 'Action, Crime, Mystery',
#        'Drama, Fantasy, Romance', 'Drama, Sci-Fi, Thriller',
#        'Biography, Drama, History', 'Action, Crime, Horror',
#        'Crime, Thriller', 'Comedy, Crime, Drama',
#        'Drama, Mystery, Thriller', 'Action, Adventure, Mystery',
# ...

# %%
df.GENRE.nunique()
# Out:
# 455
